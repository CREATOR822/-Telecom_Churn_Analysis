# %% [markdown]
# # Telecom Churn Analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Python_Case_Studytop.csv")

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # Data info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# # plotting columns data

# %%
import seaborn as sns

# %%
sns.histplot(df['International plan'])
# Out:
# <AxesSubplot:xlabel='International plan', ylabel='Count'>

# %%
sns.histplot(df['Voice mail plan'])
# Out:
# <AxesSubplot:xlabel='Voice mail plan', ylabel='Count'>

# %%
sns.histplot(df['Total day calls'])
# Out:
# <AxesSubplot:xlabel='Total day calls', ylabel='Count'>

# %%
sns.histplot(df['Total day charge'])
# Out:
# <AxesSubplot:xlabel='Total day charge', ylabel='Count'>

# %%
sns.scatterplot(df['Total day calls'], df['Total day charge'])
# Out:
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total day calls', ylabel='Total day charge'>

# %%
sns.scatterplot(df['Total day calls'], df['Total night calls'])
# Out:
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total day calls', ylabel='Total night calls'>

# %%
sns.boxplot(df['Churn'],df['Total eve minutes'])
# Out:
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='Total eve minutes'>

# %%
sns.boxplot(df['Churn'],df['Total day charge'])
# Out:
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='Total day charge'>

# %% [markdown]
# # Applying Encodeing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Churn']=le.fit_transform(df['Churn'])

# %%
df.Churn.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['International plan']=le.fit_transform(df['International plan'])

# %%
df['International plan']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 2661    0
# 2662    0
# 2663    0
# 2664    0
# 2665    0
# Name: International plan, Length: 2666, dtype: int32

# %%
df['Voice mail plan']=le.fit_transform(df['Voice mail plan'])

# %%
df['Voice mail plan']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2661    0
# 2662    1
# 2663    0
# 2664    0
# 2665    1
# Name: Voice mail plan, Length: 2666, dtype: int32

# %% [markdown]
# # plotting heat map

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(15,11))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415                   0                1
# 1    OH             107        415                   0                1
# 2    NJ             137        415                   0                0
# 3    OH              84        408                   1                0
# 4    OK              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # dropping unwanted colunms

# %%
df.drop(df['Voice mail plan'], inplace=True)

# %%
df.drop('Number vmail messages', axis=1, inplace=True)

# %%
df.drop('Voice mail plan', axis=1, inplace=True)

# %%
df.drop('Total intl calls', axis=1, inplace=True)

# %%
plt.figure(figsize=(15,11))
cor = df.corr()
sns.heatmap(cor,annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# # one_hot Encoding on States

# %%
dm=pd.get_dummies(df.State)

# %%
ndf=pd.concat([df,dm], axis=1)

# %%
ndf.drop('State', axis=1, inplace=True)

# %% [markdown]
# # creating X, Y variables

# %%
x = ndf.drop('Churn', axis=1)
y = ndf.Churn

# %%
x.shape, y.shape
# Out:
# ((2664, 66), (2664,))

# %%
y.value_counts()
# Out:
# 0    2276
# 1     388
# Name: Churn, dtype: int64

# %%
x
# Out:
#       Account length  Area code  International plan  Total day minutes  \
# 2                137        415                   0              243.4
# 3                 84        408                   1              299.4
# 4                 75        415                   1              166.7
# 5                118        510                   1              223.4
# 6                121        510                   0              218.2
# ...              ...        ...                 ...                ...
# 2661              79        415                   0              134.7
# 2662             192        415                   0              156.2
# 2663              68        415                   0              231.1
# 2664              28        510                   0              180.8
# 2665              74        415                   0              234.4
#
#       Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# ...

# %% [markdown]
# # applying ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(x, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.02403232 0.01537742 0.07652706 0.11211388 0.02385885 0.11662772
#  0.05894635 0.02517448 0.05886385 0.02843283 0.02489492 0.02875723
#  0.04633648 0.04421559 0.13135055 0.0028907  0.00292138 0.00432456
#  0.00129574 0.00187295 0.00342644 0.00537424 0.00208318 0.00277568
#  0.00160003 0.00340748 0.00121191 0.00432722 0.00194206 0.00447656
#  0.0024503  0.00353255 0.0023778  0.00145109 0.00357532 0.00376232
#  0.00563088 0.00377034 0.00692861 0.00310481 0.00490898 0.00185298
#  0.00587251 0.00423506 0.00135789 0.00299275 0.00735213 0.00123198
#  0.00505911 0.0035016  0.00401078 0.00175808 0.00591635 0.00750318
#  0.00162384 0.00214679 0.00418447 0.00197192 0.00973874 0.00351612
#  0.00467857 0.00295969 0.00547605 0.00450031 0.00099506 0.00463137]

# %% [markdown]
# # plot import features

# %%
plt.figure(figsize = (12,10))
feat_importances = pd.Series(selection.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # prepare data for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 11)

# %% [markdown]
# # applying multiple models at same time

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LogisticRegression

# %%
model = [DecisionTreeRegressor,SVR,RandomForestRegressor,KNeighborsRegressor,AdaBoostRegressor,LogisticRegression]

for mod in model:
    reg = mod()
    reg = reg.fit(x_train,y_train)
    print(mod , 'accuracy',reg.score(x_test,y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> accuracy -0.11503247915707648
# <class 'sklearn.svm._classes.SVR'> accuracy -0.005483638683277281
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> accuracy 0.40683750191806045
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> accuracy -0.011917548974477166
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> accuracy 0.26998252817685
# <class 'sklearn.linear_model._logistic.LogisticRegression'> accuracy 0.86125
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # applying K-fold

# %%
from sklearn.model_selection import KFold,cross_val_score

# %% [markdown]
# # Here is loop for multiple model accuracy

# %%
models = []
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('RF', RandomForestRegressor()))
models.append(('SVM', SVR()))
models.append(('AdaBoost', AdaBoostRegressor()))
models.append(('lgr', LogisticRegression()))


results = []
names = []
for name,model in models:
    kfold = KFold(n_splits=10)
    cv_result =cross_val_score(model,x_train,y_train,cv=kfold)
    names.append(name)
    results.append(cv_result)
for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # test score on logistic reg

# %%
lgr=LogisticRegression(max_iter=6000, random_state=67)
lgr.fit(x_train, y_train)
lgr.score(x_test, y_test)
# Out:
# 0.85875

# %%
y_pred = lgr.predict(x_test)

# %%
lgr.score(x_test, y_pred)
# Out:
# 1.0

# %%
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# C:\Users\CREATOR\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,classification_report, confusion_matrix

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.14125

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.14125

# %% [markdown]
# # classification report

# %%
print(classification_report(y_test,lgr.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       686
#            1       0.51      0.21      0.30       114
#
#     accuracy                           0.86       800
#    macro avg       0.70      0.59      0.61       800
# weighted avg       0.83      0.86      0.83       800

# %%
cm = confusion_matrix(y_test, lgr.predict(x_test))
cm
# Out:
# array([[659,  23],
#        [ 87,  31]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (8,4))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(51.0, 0.5, 'Truth')
